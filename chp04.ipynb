# %%
series = {
    'index':[0,1,2,3],
    'data':[145,142,38,12],
    'name':'songs'
}

# %%
def get(series, idx):
    value_idx = series['index'].index(idx)
    return series['data'][value_idx]

get(series, 1)
# Out:
# 142

# %%
print(series['name'])
# Out:
# songs

# %%
songs = {
    'index':['Paul', 'John', 'George','Ringo'],
    'data':[145,142,38,13],
    'name':'counts'
}

# %%
get(songs, 'John')
# Out:
# 142

# %%
import pandas as pd
songs2 = pd.Series([145,142,38,13],
                   name='counts')

# %%
songs2
# Out:
# 0    145
# 1    142
# 2     38
# 3     13
# Name: counts, dtype: int64

# %%
songs2.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
songs3 = pd.Series([145,142,38,13],
                  name='counts',
                  index=['Paul', 'John', 'George','Ringo'])

# %%
songs3
# Out:
# Paul      145
# John      142
# George     38
# Ringo      13
# Name: counts, dtype: int64

# %%
songs3.index
# Out:
# Index(['Paul', 'John', 'George', 'Ringo'], dtype='object')

# %%
class Foo:
    pass

ringo = pd.Series(
    ['Richard','Starkey', 13, Foo()],
    name='ringo')

ringo
# Out:
# 0                                    Richard
# 1                                    Starkey
# 2                                         13
# 3    <__main__.Foo object at 0x7fede1d77550>
# Name: ringo, dtype: object

# %%
import numpy as np

nan_series = pd.Series([2, np.nan],
                      index=['Ono', 'Clapton'])

nan_series
# Out:
# Ono        2.0
# Clapton    NaN
# dtype: float64

# %%
nan_series.count()
# Out:
# 1

# %%
nan_series.size
# Out:
# 2

# %%
nan_series2 = pd.Series([2, None],
                       index=['Ono', 'Clapton'],
                       dtype='Int64')

# %%
nan_series2.count()
# Out:
# 1

# %%
nan_series2
# Out:
# Ono           2
# Clapton    <NA>
# dtype: Int64

# %%
nan_series.astype('Int64')
# Out:
# Ono           2
# Clapton    <NA>
# dtype: Int64

# %%
numpy_ser = np.array([145,142,38,13])

# %%
songs3[1]
# Out:
# 142

# %%
numpy_ser[1]
# Out:
# 142

# %%
songs3
# Out:
# Paul      145
# John      142
# George     38
# Ringo      13
# Name: counts, dtype: int64

# %%
songs3 > songs3.median()
# Out:
# Paul       True
# John       True
# George    False
# Ringo     False
# Name: counts, dtype: bool

# %%
songs3[songs3 > songs3.median()]
# Out:
# Paul    145
# John    142
# Name: counts, dtype: int64

# %%
songs3.mean()
# Out:
# 84.5

# %%
numpy_ser.mean()
# Out:
# 84.5

# %%
mask = songs3 > songs3.median()  # boolean array

# %%
mask
# Out:
# Paul       True
# John       True
# George    False
# Ringo     False
# Name: counts, dtype: bool

# %%
songs3[mask]
# Out:
# Paul    145
# John    142
# Name: counts, dtype: int64

# %%
numpy_ser[numpy_ser > np.median(numpy_ser)]
# Out:
# array([145, 142])

# %%
s = pd.Series(['m','l','xs','s','xl'], dtype='category')

# %%
s
# Out:
# 0     m
# 1     l
# 2    xs
# 3     s
# 4    xl
# dtype: category
# Categories (5, object): ['l', 'm', 's', 'xl', 'xs']

# %%
s.cat.ordered
# Out:
# False

# %%
s2 = pd.Series(['m', 'l', 'xs', 's', 'xl'])
size_type = pd.api.types.CategoricalDtype(categories=['s', 'm','l'], ordered=True)
s3 = s2.astype(size_type)

# %%
s3
# Out:
# 0      m
# 1      l
# 2    NaN
# 3      s
# 4    NaN
# dtype: category
# Categories (3, object): ['s' < 'm' < 'l']

# %%
s3 > 's'
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
s3[s3 > 's']
# Out:
# 0    m
# 1    l
# dtype: category
# Categories (3, object): ['s' < 'm' < 'l']

# %%
s.cat.reorder_categories(['xs','s', 'm', 'l', 'xl'], ordered=True)
# Out:
# 0     m
# 1     l
# 2    xs
# 3     s
# 4    xl
# dtype: category
# Categories (5, object): ['xs' < 's' < 'm' < 'l' < 'xl']

# %%
last_7_days = pd.Series([34,41,45,39,37,39,41],
               index=['Dec 31', 'Jan 01', 'Jan 02', 'Jan 03', 'Jan 04', 'Jan 05', 'Jan 06'],
               name='temperature')

# %%
last_7_days
# Out:
# Dec 31    34
# Jan 01    41
# Jan 02    45
# Jan 03    39
# Jan 04    37
# Jan 05    39
# Jan 06    41
# Name: temperature, dtype: int64

# %%
last_7_days.mean()
# Out:
# 39.42857142857143

# %%
last_7_days > last_7_days.mean()
# Out:
# Dec 31    False
# Jan 01     True
# Jan 02     True
# Jan 03    False
# Jan 04    False
# Jan 05    False
# Jan 06     True
# Name: temperature, dtype: bool

# %%
last_7_days[last_7_days > last_7_days.mean()]
# Out:
# Jan 01    41
# Jan 02    45
# Jan 06    41
# Name: temperature, dtype: int64

# %%
colors = pd.Series(['red', 'green', 'orange', 'black'], dtype='category')

# %%
colors
# Out:
# 0       red
# 1     green
# 2    orange
# 3     black
# dtype: category
# Categories (4, object): ['black', 'green', 'orange', 'red']
