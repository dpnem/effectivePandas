# %%
import pandas as pd
url = 'https://github.com/mattharrison/datasets/raw/master/data/vehicles.csv.zip'
df = pd.read_csv(url)
city_mpg = df.city08
highway_mpg = df.highway08

# %%
(city_mpg + highway_mpg) / 2
# Out:
# 0        22.0
# 1        11.5
# 2        28.0
# 3        11.0
# 4        20.0
#          ...
# 41139    22.5
# 41140    24.0
# 41141    21.0
# 41142    21.0
# 41143    18.5
# Length: 41144, dtype: float64

# %%
s1 = pd.Series([10, 20, 30], index=[1,2,2])
s2 = pd.Series([35, 44, 53], index=[2,2,4], name='s2')

# %%
s1
# Out:
# 1    10
# 2    20
# 2    30
# dtype: int64

# %%
s2
# Out:
# 2    35
# 2    44
# 4    53
# Name: s2, dtype: int64

# %%
s1 + s2
# Out:
# 1     NaN
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4     NaN
# dtype: float64

# %%
s1.add(s2, fill_value=0)
# Out:
# 1    10.0
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4    53.0
# dtype: float64

# %%
s1.add(s2)
# Out:
# 1     NaN
# 2    55.0
# 2    64.0
# 2    65.0
# 2    74.0
# 4     NaN
# dtype: float64

# %%
((city_mpg +
 highway_mpg)
 /2
)
# Out:
# 0        22.0
# 1        11.5
# 2        28.0
# 3        11.0
# 4        20.0
#          ...
# 41139    22.5
# 41140    24.0
# 41141    21.0
# 41142    21.0
# 41143    18.5
# Length: 41144, dtype: float64

# %%
(city_mpg
    .add(highway_mpg)
    .div(2))
# Out:
# 0        22.0
# 1        11.5
# 2        28.0
# 3        11.0
# 4        20.0
#          ...
# 41139    22.5
# 41140    24.0
# 41141    21.0
# 41142    21.0
# 41143    18.5
# Length: 41144, dtype: float64

# %%
numeric_series = pd.Series([103, 310, 155, 466, 233, 700, 350, 175, 526, 263, 790, 395, 1186, 593, 1780, 890, 445, 1336, 668, 334, 167, 502, 251, 754, 377, 1132, 566, 283, 850, 425, 1276, 638, 319, 958, 479, 1438, 719, 2158, 1079, 3238, 1619, 4858, 2429, 7288, 3644, 1822, 911, 2734, 1367, 4102, 2051, 6154, 3077, 9232, 4616, 2308, 1154, 577, 1732, 866, 433, 1300, 650, 325, 976, 488, 244, 122, 61, 184, 92, 46, 23, 70, 35, 106, 53, 160, 80, 40, 20, 10, 5, 16, 8, 4, 2, 1])

# %%
numeric_series.add(numeric_series)
# Out:
# 0     206
# 1     620
# 2     310
# 3     932
# 4     466
#      ...
# 83     32
# 84     16
# 85      8
# 86      4
# 87      2
# Length: 88, dtype: int64

# %%
numeric_series.add(10)
# Out:
# 0     113
# 1     320
# 2     165
# 3     476
# 4     243
#      ...
# 83     26
# 84     18
# 85     14
# 86     12
# 87     11
# Length: 88, dtype: int64
